# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# %%
labels = np.load('../results/softmax_labels_w.npy')
preds = np.load('../results/softmax_preds_w.npy')

# %%
i = 8000
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = 1000
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = 100
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = 110
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = 120
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = 540
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = np.random.randint(100)
plt.plot(labels[i]/np.sum(labels[i]), 'ro')
plt.plot(preds[i], 'go')

# %%
plt.hist(np.argmax(labels[:], axis=1) - np.argmax(preds[:], axis=1), histtype='step', bins=100)
# Out:
# (array([ 1721.,     0.,     0.,     0.,     0.,  2333.,     0.,     0.,
#             0.,     0.,  1386.,     0.,     0.,     0.,     0.,   985.,
#             0.,     0.,     0.,     0.,     0.,   879.,     0.,     0.,
#             0.,     0.,   904.,     0.,     0.,     0.,     0.,  1298.,
#             0.,     0.,     0.,     0.,  2127.,     0.,     0.,     0.,
#             0.,     0.,  5395.,     0.,     0.,     0.,     0., 19616.,
#             0.,     0.,     0.,     0., 35241.,     0.,     0.,     0.,
#             0., 16470.,     0.,     0.,     0.,     0.,     0.,  4586.,
#             0.,     0.,     0.,     0.,  1837.,     0.,     0.,     0.,
#             0.,   981.,     0.,     0.,     0.,     0.,   657.,     0.,
#             0.,     0.,     0.,     0.,   612.,     0.,     0.,     0.,
#             0.,   667.,     0.,     0.,     0.,     0.,  1046.,     0.,
#             0.,     0.,     0.,  1259.]),
# ...

# %%
acc0 = (np.abs(np.argmax(labels[:], axis=1) - np.argmax(preds[:], axis=1)) <= 0).mean()
acc1 = (np.abs(np.argmax(labels[:], axis=1) - np.argmax(preds[:], axis=1)) <= 1).mean()
acc2 = (np.abs(np.argmax(labels[:], axis=1) - np.argmax(preds[:], axis=1)) <= 2).mean()
acc3 = (np.abs(np.argmax(labels[:], axis=1) - np.argmax(preds[:], axis=1)) <= 3).mean()

# %%
print('Acc0', acc0)
print('Acc1', acc1)
print('Acc2', acc2)
print('Acc3', acc3)
# Out:
# Acc0 0.35241
# Acc1 0.71327
# Acc2 0.81308
# Acc3 0.85272
