# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# %%
labels = np.load('../results/softmax_labels_w.npy')
preds = np.load('../results/softmax_preds_w.npy')

# %%
i = 8000
label = labels[i]/np.sum(labels[i])
pred = preds[i]
print(label.sum())
print(pred.sum())
plt.plot(label, 'o')
plt.plot(pred, 'o')
# Out:
# 1.0
# 1.0

# %%
i = 1000
label = labels[i]/np.sum(labels[i])
pred = preds[i]
print(label.sum())
print(pred.sum())
plt.plot(label, 'o')
plt.plot(pred, 'o')
# Out:
# 1.0
# 1.0000001

# %%
i = 100
label = labels[i]/np.sum(labels[i])
pred = preds[i]
print(label.sum())
print(pred.sum())
plt.plot(label, 'o')
plt.plot(pred, 'o')
# Out:
# 1.0000000000000002
# 1.0

# %%
i = 110
label = labels[i]/np.sum(labels[i])
pred = preds[i]
print(label.sum())
print(pred.sum())
plt.plot(label, 'o')
plt.plot(pred, 'o')
# Out:
# 1.0
# 0.99999994

# %%
i = 120
label = labels[i]/np.sum(labels[i])
pred = preds[i]
print(label.sum())
print(pred.sum())
plt.plot(label, 'o')
plt.plot(pred, 'o')
# Out:
# 0.9999999999999997
# 1.0

# %%
i = 540
label = labels[i]/np.sum(labels[i])
pred = preds[i]
print(label.sum())
print(pred.sum())
plt.plot(label, 'o')
plt.plot(pred, 'o')
# Out:
# 0.9999999999999999
# 0.99999994

# %%
i = np.random.randint(100)
label = labels[i]/np.sum(labels[i])
pred = preds[i]
print(label.sum())
print(pred.sum())
plt.plot(label, 'o')
plt.plot(pred, 'o')
# Out:
# 0.9999999999999999
# 1.0
