# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# %%
labels = np.load('../results/softmax_labels_w.npy')
preds = np.load('../results/softmax_preds_w.npy')

# %%
i = 8000
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = 1000
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = 100
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = 110
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = 120
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = 540
plt.plot(labels[i]/np.sum(labels[i]), 'o')
plt.plot(preds[i], 'o')

# %%
i = np.random.randint(100)
plt.plot(labels[i]/np.sum(labels[i]), 'ro')
plt.plot(preds[i], 'go')

# %%
plt.hist(labels[:]/np.sum(labels[:]) - preds[:])
# Out:
# ([array([0.0000e+00, 0.0000e+00, 1.4000e+01, 8.0600e+02, 1.2093e+04,
#          3.0325e+04, 3.2159e+04, 1.6799e+04, 7.2650e+03, 5.3900e+02]),
#   array([0.0000e+00, 1.0000e+00, 8.4000e+01, 2.2400e+03, 1.3649e+04,
#          2.7366e+04, 3.1103e+04, 1.7159e+04, 7.7960e+03, 6.0200e+02]),
#   array([0.0000e+00, 1.0000e+01, 3.2100e+02, 3.8380e+03, 1.4039e+04,
#          2.5953e+04, 2.9835e+04, 1.6932e+04, 8.2230e+03, 8.4900e+02]),
#   array([2.0000e+00, 4.0000e+01, 5.7300e+02, 4.4740e+03, 1.4678e+04,
#          2.5684e+04, 2.9475e+04, 1.6271e+04, 7.9630e+03, 8.4000e+02]),
#   array([8.0000e+00, 1.0500e+02, 9.3700e+02, 5.3630e+03, 1.4152e+04,
#          2.4298e+04, 3.0645e+04, 1.6868e+04, 7.0890e+03, 5.3500e+02]),
#   array([1.6000e+01, 1.4900e+02, 1.1600e+03, 6.0280e+03, 1.3674e+04,
#          2.2609e+04, 3.0857e+04, 1.8293e+04, 6.8910e+03, 3.2300e+02]),
#   array([1.1000e+01, 1.0100e+02, 9.8200e+02, 5.6940e+03, 1.4269e+04,
#          2.2055e+04, 3.0550e+04, 1.7312e+04, 8.3700e+03, 6.5600e+02]),
#   array([2.0000e+00, 4.4000e+01, 5.7300e+02, 4.3620e+03, 1.3806e+04,
#          2.3413e+04, 3.0911e+04, 1.6922e+04, 9.0260e+03, 9.4100e+02]),
#   array([0.0000e+00, 7.0000e+00, 1.9400e+02, 2.7270e+03, 1.2745e+04,
#          2.4710e+04, 3.2485e+04, 1.8255e+04, 8.1830e+03, 6.9400e+02]),
#   array([0.0000e+00, 0.0000e+00, 2.7000e+01, 1.1930e+03, 1.1898e+04,
#          2.7458e+04, 3.3807e+04, 1.7935e+04, 7.1480e+03, 5.3400e+02]),
#   array([0.0000e+00, 0.0000e+00, 1.5000e+01, 7.7000e+02, 1.2042e+04,
#          3.0447e+04, 3.2157e+04, 1.6744e+04, 7.2840e+03, 5.4100e+02])],
#  array([-0.22930786, -0.2069439 , -0.18457995, -0.16221599, -0.13985203,
#         -0.11748808, -0.09512412, -0.07276017, -0.05039621, -0.02803226,
#         -0.0056683 ]),
#  <a list of 11 Lists of Patches objects>)
