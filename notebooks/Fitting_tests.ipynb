# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# %%
ls ../data
# Out:
# arg_maxs.npy
# popts.npy
# pythia.H.rhorho.1M.a.pseudoscalar.outTUPLE_labFrame
# pythia.H.rhorho.1M.a.scalar.outTUPLE_labFrame
# rhorho_raw.data.npy
# rhorho_raw.perm.npy
# rhorho_raw.w.npy
# rhorho_raw.w_a.npy
# rhorho_raw.w_a02.npy
# rhorho_raw.w_a04.npy
# rhorho_raw.w_a06.npy
# rhorho_raw.w_a08.npy
# rhorho_raw.w_b.npy
# weigths.npy

# %%
popts = np.load('../data/popts.npy')
pcovs = np.load('../data/pcovs.npy')

# %%
weights = np.load('../data/rhorho_raw.w.npy')

# %%
def weight_fun(x, a, b, c):
    return a + b * np.cos(x) + c * np.sin(x)

# %%
x_weights = np.array([0, 0.2, 0.4, 0.6, 0.8, 1, 1.2, 1.4, 1.6, 1.8, 2]) * np.pi
x_fit = np.linspace(0, 2*np.pi)

# %%
i = 0 
plt.plot(x_weights, weights[:,i], 'o')
plt.plot(x_fit, weight_fun(x_fit, *popts[i]))
plt.xlabel('2Φ')
plt.ylabel('w')
print('error: ' + str(np.sqrt(np.diag(pcovs[i]))))
# Out:
# error: [6.89285202e-08 9.33296578e-08 1.01460033e-07]

# %%
# Out:
# array([[ 4.75114090e-15, -7.91856814e-16, -1.49294929e-24],
#        [-7.91856814e-16,  8.71042503e-15,  1.64224423e-23],
#        [-1.49294929e-24,  1.64224423e-23,  1.02941383e-14]])

# %%
i = 10 
plt.plot(x_weights, weights[:,i], 'o')
plt.plot(x_fit, weight_fun(x_fit, *popts[i]))
plt.xlabel('2Φ')
plt.ylabel('w')
print('error: ' + str(np.sqrt(np.diag(pcovs[i]))))
# Out:
# error: [9.66112155e-08 1.30812205e-07 1.42207888e-07]

# %%
i = 1000 
plt.plot(x_weights, weights[:,i], 'o')
plt.plot(x_fit, weight_fun(x_fit, *popts[i]))
plt.xlabel('2Φ')
plt.ylabel('w')
print('error: ' + str(np.sqrt(np.diag(pcovs[i]))))
# Out:
# error: [8.66461032e-08 1.17319378e-07 1.27539609e-07]

# %%
i = 2000 
plt.plot(x_weights, weights[:,i], 'o')
plt.plot(x_fit, weight_fun(x_fit, *popts[i]))
plt.xlabel('2Φ')
plt.ylabel('w')
print('error: ' + str(np.sqrt(np.diag(pcovs[i]))))
# Out:
# error: [9.88574560e-08 1.33853626e-07 1.45514234e-07]

# %%
i = 8000 
plt.plot(x_weights, weights[:,i], 'o')
plt.plot(x_fit, weight_fun(x_fit, *popts[i]))
plt.xlabel('2Φ')
plt.ylabel('w')
print('error: ' + str(np.sqrt(np.diag(pcovs[i]))))
# Out:
# error: [9.42869505e-08 1.27665135e-07 1.38786634e-07]

# %%
i = 10000 
plt.plot(x_weights, weights[:,i], 'o')
plt.plot(x_fit, weight_fun(x_fit, *popts[i]))
plt.xlabel('2Φ')
plt.ylabel('w')
print('error: ' + str(np.sqrt(np.diag(pcovs[i]))))
# Out:
# error: [1.07115820e-07 1.45035506e-07 1.57670215e-07]
